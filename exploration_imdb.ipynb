# %%
import pandas as pd

# %%
df_imdb_principals = pd.read_csv("title.principals.tsv", sep="\t")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_imdb_principals = pd.read_csv("title.principals.tsv", sep="\t")
#
# File c:\Anaconda\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df_imdb_principals
# Out:
#              tconst  ordering     nconst         category  \
# 0         tt0000001         1  nm1588970             self
# 1         tt0000001         2  nm0005690         director
# 2         tt0000001         3  nm0005690         producer
# 3         tt0000001         4  nm0374658  cinematographer
# 4         tt0000002         1  nm0721526         director
# ...             ...       ...        ...              ...
# 92540003  tt9916880        17  nm0996406         director
# 92540004  tt9916880        18  nm1482639           writer
# 92540005  tt9916880        19  nm2586970           writer
# 92540006  tt9916880        20  nm1594058         producer
# 92540007  tt9916880        21  nm1482639         producer
#
#                               job characters
# 0                              \N   ["Self"]
# 1                              \N         \N
# 2                        producer         \N
# 3         director of photography         \N
# ...

# %%
mask1 = (df_imdb_principals["category"] == "director") 
mask2 = (df_imdb_principals["category"] == "actor")

# %%
df_imdb_principals_actors_directors = df_imdb_principals[mask1|mask2]

# %%
df_imdb_principals_actors_directors
# Out:
#              tconst  ordering     nconst  category                 job  \
# 1         tt0000001         2  nm0005690  director                  \N
# 4         tt0000002         1  nm0721526  director                  \N
# 6         tt0000003         1  nm0721526  director                  \N
# 12        tt0000004         1  nm0721526  director                  \N
# 14        tt0000005         1  nm0443482     actor                  \N
# ...             ...       ...        ...       ...                 ...
# 92539990  tt9916880         4  nm1483166     actor                  \N
# 92539992  tt9916880         6  nm0286175     actor                  \N
# 92539993  tt9916880         7  nm0286175     actor                  \N
# 92539994  tt9916880         8  nm0286175     actor                  \N
# 92540003  tt9916880        17  nm0996406  director  principal director
#
#                 characters
# 1                       \N
# 4                       \N
# 6                       \N
# ...

# %%
df_imdb_ratings = pd.read_csv("title.ratings.tsv", sep="\t")

# %%
df_imdb_ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2157
# 1        tt0000002            5.5       293
# 2        tt0000003            6.5      2194
# 3        tt0000004            5.3       187
# 4        tt0000005            6.2      2942
# ...            ...            ...       ...
# 1567160  tt9916846            5.8         6
# 1567161  tt9916848            5.8         6
# 1567162  tt9916850            5.8         6
# 1567163  tt9916852            5.8         6
# 1567164  tt9916880            7.7        10
#
# [1567165 rows x 3 columns]

# %%
df_imdb_name_basics = pd.read_csv("name.basics.tsv", sep="\t")

# %%
df_imdb_name_basics
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 14371719  nm9993714   Romeo del Rosario        \N        \N
# 14371720  nm9993716       Essias Loberg        \N        \N
# 14371721  nm9993717  Harikrishnan Rajan        \N        \N
# 14371722  nm9993718         Aayush Nair        \N        \N
# 14371723  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0                actor,miscellaneous,producer
# 1          actress,soundtrack,archive_footage
# 2           actress,music_department,producer
# 3               actor,writer,music_department
# ...

# %%
df_imdb_title_basics = pd.read_csv("title.basics.tsv", sep="\t")
# Out:
# /var/folders/rk/8pzvl099435clcdyv92yg08h0000gn/T/ipykernel_63783/3518494202.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_imdb_title_basics = pd.read_csv("title.basics.tsv", sep="\t")

# %%
df_imdb_title_basics
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short               Poor Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 11655939  tt9916848  tvEpisode              Episode #3.17
# 11655940  tt9916850  tvEpisode              Episode #3.19
# 11655941  tt9916852  tvEpisode              Episode #3.20
# 11655942  tt9916856      short                   The Wind
# 11655943  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# ...

# %%
df_imdb_title_basics["titleType"].unique()
# Out:
# array(['short', 'movie', 'tvShort', 'tvMovie', 'tvEpisode', 'tvSeries',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame', 'tvPilot'],
#       dtype=object)

# %%
df_imdb_title_basics = df_imdb_title_basics[df_imdb_title_basics["titleType"] == "movie"]
df_imdb_title_basics = df_imdb_title_basics[df_imdb_title_basics["isAdult"] == 0]

# %%
df_imdb_title_basics
# Out:
#              tconst titleType  \
# 8         tt0000009     movie
# 144       tt0000147     movie
# 498       tt0000502     movie
# 570       tt0000574     movie
# 587       tt0000591     movie
# ...             ...       ...
# 11655835  tt9916622     movie
# 11655862  tt9916680     movie
# 11655874  tt9916706     movie
# 11655884  tt9916730     movie
# 11655894  tt9916754     movie
#
#                                                primaryTitle  \
# 8                                                Miss Jerry
# 144                           The Corbett-Fitzsimmons Fight
# 498                                                Bohemios
# 570                             The Story of the Kelly Gang
# 587                                        The Prodigal Son
# ...                                                     ...
# 11655835        Rodolpho Teóphilo - O Legado de um Pioneiro
# 11655862  De la ilusión al desconcierto: cine colombiano...
# ...

# %%
df_imdb = pd.merge(df_imdb_title_basics,  # DataFrame de gauche
         df_imdb_ratings,  # DataFrame de droite
         how="left",  # Type de jointure : ici, une jointure gauche (left join)
         left_on='tconst',  # Colonne clé du DataFrame de gauche
         right_on='tconst')  # Colonne clé du DataFrame de droite

# %%
df_imdb
# Out:
#            tconst titleType  \
# 0       tt0000009     movie
# 1       tt0000147     movie
# 2       tt0000502     movie
# 3       tt0000574     movie
# 4       tt0000591     movie
# ...           ...       ...
# 703218  tt9916622     movie
# 703219  tt9916680     movie
# 703220  tt9916706     movie
# 703221  tt9916730     movie
# 703222  tt9916754     movie
#
#                                              primaryTitle  \
# 0                                              Miss Jerry
# 1                           The Corbett-Fitzsimmons Fight
# 2                                                Bohemios
# 3                             The Story of the Kelly Gang
# 4                                        The Prodigal Son
# ...                                                   ...
# 703218        Rodolpho Teóphilo - O Legado de um Pioneiro
# 703219  De la ilusión al desconcierto: cine colombiano...
# 703220                                    Dankyavar Danka
# ...

# %%
df_imdb_name_basics = pd.read_csv("name.basics.tsv", sep="\t")

# %%
df_imdb_name_basics
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 14371719  nm9993714   Romeo del Rosario        \N        \N
# 14371720  nm9993716       Essias Loberg        \N        \N
# 14371721  nm9993717  Harikrishnan Rajan        \N        \N
# 14371722  nm9993718         Aayush Nair        \N        \N
# 14371723  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0                actor,miscellaneous,producer
# 1          actress,soundtrack,archive_footage
# 2           actress,music_department,producer
# 3               actor,writer,music_department
# ...

# %%
df_imdb_name = pd.merge(df_imdb_principals_actors_directors,  # DataFrame de gauche
         df_imdb_name_basics,  # DataFrame de droite
         how="left",  # Type de jointure : ici, une jointure gauche (left join)
         left_on='nconst',  # Colonne clé du DataFrame de gauche
         right_on='nconst')  # Colonne clé du DataFrame de droite

# %%
df_imdb_name
# Out:
#              tconst  ordering     nconst  category                 job  \
# 0         tt0000001         2  nm0005690  director                  \N
# 1         tt0000002         1  nm0721526  director                  \N
# 2         tt0000003         1  nm0721526  director                  \N
# 3         tt0000004         1  nm0721526  director                  \N
# 4         tt0000005         1  nm0443482     actor                  \N
# ...             ...       ...        ...       ...                 ...
# 29900727  tt9916880         4  nm1483166     actor                  \N
# 29900728  tt9916880         6  nm0286175     actor                  \N
# 29900729  tt9916880         7  nm0286175     actor                  \N
# 29900730  tt9916880         8  nm0286175     actor                  \N
# 29900731  tt9916880        17  nm0996406  director  principal director
#
#                 characters           primaryName birthYear deathYear  \
# ...

# %%
df_imdb_final_ok = pd.merge(df_imdb,  # DataFrame de gauche
         df_imdb_name,  # DataFrame de droite
         how="left",  # Type de jointure : ici, une jointure gauche (left join)
         left_on='tconst',  # Colonne clé du DataFrame de gauche
         right_on='tconst')  # Colonne clé du DataFrame de droite

# %%
df_imdb_final_ok
# Out:
#             tconst titleType                    primaryTitle  \
# 0        tt0000009     movie                      Miss Jerry
# 1        tt0000009     movie                      Miss Jerry
# 2        tt0000009     movie                      Miss Jerry
# 3        tt0000147     movie   The Corbett-Fitzsimmons Fight
# 4        tt0000502     movie                        Bohemios
# ...            ...       ...                             ...
# 3236516  tt9916730     movie                          6 Gunn
# 3236517  tt9916730     movie                          6 Gunn
# 3236518  tt9916730     movie                          6 Gunn
# 3236519  tt9916730     movie                          6 Gunn
# 3236520  tt9916754     movie  Chico Albuquerque - Revelações
#
#                           originalTitle isAdult startYear endYear  \
# 0                            Miss Jerry       0      1894      \N
# 1                            Miss Jerry       0      1894      \N
# ...

# %%
df_imdb_final = df_imdb_final_ok.drop(["birthYear","deathYear"], axis=1)
df_imdb_final = df_imdb_final_ok.drop(["titleType","isAdult", "endYear", "job", "knownForTitles"], axis=1)

# %%
df_imdb_final
# Out:
#             tconst                    primaryTitle  \
# 0        tt0000009                      Miss Jerry
# 1        tt0000009                      Miss Jerry
# 2        tt0000009                      Miss Jerry
# 3        tt0000147   The Corbett-Fitzsimmons Fight
# 4        tt0000502                        Bohemios
# ...            ...                             ...
# 3236516  tt9916730                          6 Gunn
# 3236517  tt9916730                          6 Gunn
# 3236518  tt9916730                          6 Gunn
# 3236519  tt9916730                          6 Gunn
# 3236520  tt9916754  Chico Albuquerque - Revelações
#
#                           originalTitle startYear runtimeMinutes  \
# 0                            Miss Jerry      1894             45
# 1                            Miss Jerry      1894             45
# 2                            Miss Jerry      1894             45
# 3         The Corbett-Fitzsimmons Fight      1897            100
# ...

# %%
df_imdb_final = df_imdb_final_ok.groupby(['tconst', 'primaryTitle', 'startYear', 'genres','originalTitle', 'averageRating', "numVotes"], as_index=False).agg({'nconst': list, 'category': list, 'characters': list, "primaryName":list, "primaryProfession":list})
df_imdb_final.head()
# Out:
#       tconst                   primaryTitle startYear  \
# 0  tt0000009                     Miss Jerry      1894
# 1  tt0000147  The Corbett-Fitzsimmons Fight      1897
# 2  tt0000502                       Bohemios      1905
# 3  tt0000574    The Story of the Kelly Gang      1906
# 4  tt0000591               The Prodigal Son      1907
#
#                        genres                  originalTitle  averageRating  \
# 0                     Romance                     Miss Jerry            5.4
# 1      Documentary,News,Sport  The Corbett-Fitzsimmons Fight            5.3
# 2                          \N                       Bohemios            3.8
# 3  Action,Adventure,Biography    The Story of the Kelly Gang            6.0
# 4                       Drama              L'enfant prodigue            5.6
#
#    numVotes                                             nconst  \
# 0     224.0                  [nm0183823, nm1309758, nm0085156]
# ...

# %%
df_tmdb = pd.read_csv("tmdb_full.csv")
df_tmdb.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_tmdb = pd.read_csv("tmdb_full.csv")
#       2 df_tmdb.head()
#
# File c:\Anaconda\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df_tmdb["overview"][0]
# Out:
# 'Blondie and Dagwood are about to celebrate their fifth wedding anniversary but this happy occasion is marred when the bumbling Dagwood gets himself involved in a scheme that is promising financial ruin for the Bumstead family.'

# %%
df_tmdb = df_tmdb[["imdb_id", "original_language", "overview", "production_companies_name", "production_companies_country"]]
df_tmdb.head()
# Out:
#      imdb_id original_language  \
# 0  tt0029927                en
# 1  tt0011436                de
# 2  tt0055747                fr
# 3  tt0094675                fi
# 4  tt0092149                fi
#
#                                             overview  \
# 0  Blondie and Dagwood are about to celebrate the...
# 1                                                NaN
# 2  Love at Twenty unites five directors from five...
# 3  Taisto Kasurinen is a Finnish coal miner whose...
# 4  An episode in the life of Nikander, a garbage ...
#
#                            production_companies_name  \
# 0                              ['Columbia Pictures']
# 1                                                 []
# 2  ['Ulysse Productions', 'Unitec Films', 'Cinese...
# 3                      ['Villealfa Filmproductions']
# 4                      ['Villealfa Filmproductions']
#
#              production_companies_country
# 0                                  ['US']
# ...

# %%
df_tmdb.isna().sum()
# Out:
# imdb_id                              0
# original_language                    0
# overview                         27060
# production_companies_name            0
# production_companies_country    145134
# dtype: int64

# %%
df_imdb = pd.merge(df_imdb_final,  # DataFrame de gauche
         df_tmdb,  # DataFrame de droite
         how="left",  # Type de jointure : ici, une jointure gauche (left join)
         left_on='tconst',  # Colonne clé du DataFrame de gauche
         right_on='imdb_id')  # Colonne clé du DataFrame de droite

# %%
df_imdb.head()
# Out:
#       tconst                   primaryTitle startYear  \
# 0  tt0000009                     Miss Jerry      1894
# 1  tt0000147  The Corbett-Fitzsimmons Fight      1897
# 2  tt0000502                       Bohemios      1905
# 3  tt0000574    The Story of the Kelly Gang      1906
# 4  tt0000591               The Prodigal Son      1907
#
#                        genres                  originalTitle  averageRating  \
# 0                     Romance                     Miss Jerry            5.4
# 1      Documentary,News,Sport  The Corbett-Fitzsimmons Fight            5.3
# 2                          \N                       Bohemios            3.8
# 3  Action,Adventure,Biography    The Story of the Kelly Gang            6.0
# 4                       Drama              L'enfant prodigue            5.6
#
#    numVotes                                             nconst  \
# 0     224.0                  [nm0183823, nm1309758, nm0085156]
# ...

# %%
import pandas as pd
df_full = pd.read_csv("tmdb_full.csv")
df_full.head()
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_5836\529108949.py:2: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_full = pd.read_csv("tmdb_full.csv")
#    adult                     backdrop_path  budget  \
# 0  False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg       0
# 1  False                               NaN       0
# 2  False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg       0
# 3  False  /hQ4pYsIbP22TMXOUdSfC2mjWrO0.jpg       0
# 4  False  /l94l89eMmFKh7na2a1u5q67VgNx.jpg       0
#
#                            genres homepage    id    imdb_id original_language  \
# 0                      ['Comedy']      NaN  3924  tt0029927                en
# 1                   ['Adventure']      NaN  6124  tt0011436                de
# 2            ['Drama', 'Romance']      NaN  8773  tt0055747                fr
# 3    ['Drama', 'Comedy', 'Crime']      NaN     2  tt0094675                fi
# ...
